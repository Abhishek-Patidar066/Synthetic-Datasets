# %%
from numpy.linalg import *
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
df1 = np.random.randint(50,60,size=(500,1))
df2 = np.hstack((df1,np.random.randint(100,201,size=(500,1))))
df2 = pd.DataFrame(df2)

df3 = np.random.randint(60,101,size=(500,1))
df4 = np.hstack((df3,np.random.randint(190,201,size=(500,1))))
df4 = pd.DataFrame(df4)

df5 = np.random.randint(90,101,size=(500,1))
df6 = np.hstack((df5,np.random.randint(100,201,size=(500,1))))
df6 = pd.DataFrame(df6)

df7 = np.random.randint(60,101,size=(500,1))
df8 = np.hstack((df7,np.random.randint(150,160,size=(500,1))))
df8 = pd.DataFrame(df8)

finaldfa = np.vstack((df2,df4,df6,df8))
finaldfa = pd.DataFrame(finaldfa)

plt.scatter(finaldfa[0],finaldfa[1])
plt.yticks([150,200])
plt.xticks(np.arange(0,151,30))
plt.show()

# %%
df1 = np.random.randint(50,60,size=(500,1))
df2 = np.hstack((df1,np.random.randint(100,201,size=(500,1))))
df2 = pd.DataFrame(df2)

df3 = np.random.randint(60,101,size=(500,1))
df4 = np.hstack((df3,np.random.randint(190,201,size=(500,1))))
df4 = pd.DataFrame(df4)

df5 = np.random.randint(90,101,size=(500,1))
df6 = np.hstack((df5,np.random.randint(100,201,size=(500,1))))
df6 = pd.DataFrame(df6)

df7 = np.random.randint(60,101,size=(500,1))
df8 = np.hstack((df7,np.random.randint(150,160,size=(500,1))))
df8 = pd.DataFrame(df8)

df9 = np.random.randint(60,101,size=(500,1))
df10 = np.hstack((df9,np.random.randint(101,110,size=(500,1))))
df10 = pd.DataFrame(df10)

finaldfb = np.vstack((df2,df4,df6,df8,df10))
finaldfb = pd.DataFrame(finaldfb)

plt.scatter(finaldfb[0],finaldfb[1])
plt.yticks([150,200])
plt.xticks(np.arange(0,151,30))
plt.show()

# %%
df1 = np.random.randint(50,70,size=(500,1))

df2 = np.hstack((df1,np.random.randint(100,201,size=(500,1))))
df2 = pd.DataFrame(df2)

df3 = np.random.randint(81,101,size=(500,1))
df4 = np.hstack((df3,np.random.randint(100,201,size=(500,1))))
df4 = pd.DataFrame(df4)

df5 = np.random.randint(70,81,size=(100,1))
df6 = np.hstack((df5,np.random.randint(140,151,size=(100,1))))
df6 = pd.DataFrame(df6)

finaldfh = np.vstack((df2,df4,df6))
finaldfh = pd.DataFrame(finaldfh)
finaldfh

plt.scatter(finaldfh[0],finaldfh[1])
plt.yticks([150,200])
plt.xticks(np.arange(0,151,30))
plt.show()

# %%
df1 = np.random.randint(48,60,size=(500,1))
df2 = np.hstack((df1,np.random.randint(100,201,size=(500,1))))
df2 = pd.DataFrame(df2)

df3 = np.random.randint(30,80,size=(500,1))
df4 = np.hstack((df3,np.random.randint(190,201,size=(500,1))))
df4 = pd.DataFrame(df4)

df5 = np.random.randint(30,80,size=(500,1))
df6 = np.hstack((df5,np.random.randint(100,110,size=(500,1))))
df6 = pd.DataFrame(df6)

finaldfi = np.vstack((df2,df4,df6))
finaldfi = pd.DataFrame(finaldfi)

plt.scatter(finaldfi[0],finaldfi[1])
plt.yticks([150,200])
plt.xticks(np.arange(0,151,30))
plt.show()

# %%
df1 = np.random.randint(50,60,size=(500,1))
df2 = np.hstack((df1,np.random.randint(151,201,size=(500,1))))
df2 = pd.DataFrame(df2)

df3 = np.random.randint(60,101,size=(500,1))
df4 = np.hstack((df3,np.random.randint(190,201,size=(500,1))))
df4 = pd.DataFrame(df4)

df5 = np.random.randint(90,101,size=(500,1))
df6 = np.hstack((df5,np.random.randint(100,151,size=(500,1))))
df6 = pd.DataFrame(df6)

df7 = np.random.randint(60,101,size=(500,1))
df8 = np.hstack((df7,np.random.randint(150,160,size=(500,1))))
df8 = pd.DataFrame(df8)

df9 = np.random.randint(50,101,size=(500,1))
df10 = np.hstack((df9,np.random.randint(101,110,size=(500,1))))
df10 = pd.DataFrame(df10)

finaldfs = np.vstack((df2,df4,df6,df8,df10))
finaldfs = pd.DataFrame(finaldfs)

plt.scatter(finaldfs[0],finaldfs[1])
plt.yticks([150,200])
plt.xticks(np.arange(0,151,30))
plt.show()

# %%
df1 = np.random.randint(50,60,size=(500,1))
df2 = np.hstack((df1,np.random.randint(100,201,size=(500,1))))
df2 = pd.DataFrame(df2)

df3 = np.random.randint(60,101,size=(500,1))
df4 = np.hstack((df3,np.random.randint(190,201,size=(500,1))))
df4 = pd.DataFrame(df4)

df5 = np.random.randint(60,101,size=(500,1))
df6 = np.hstack((df5,np.random.randint(150,160,size=(500,1))))
df6 = pd.DataFrame(df6)

df7 = np.random.randint(60,101,size=(500,1))
df8 = np.hstack((df7,np.random.randint(101,110,size=(500,1))))
df8 = pd.DataFrame(df8)

finaldfe = np.vstack((df2,df4,df6,df8))
finaldfe = pd.DataFrame(finaldfe)

plt.scatter(finaldfe[0],finaldfe[1])
plt.yticks([150,200])
plt.xticks(np.arange(0,151,30))
plt.show()

# %%
x = np.arange(50,100)
y = np.arange(50,100)
xy = np.vstack((x,y))
df = pd.DataFrame(xy)
df = df.T
noise = np.random.normal(0, 1.5, df.shape)
df1 = df + noise

x = np.arange(50,0,-1)
y = np.arange(1,51)+50
yx = np.vstack((y,x))
df = pd.DataFrame(yx)
df = df.T
noise = np.random.normal(0, 1.5, df.shape)
df2 = df + noise

df = np.vstack((df1,df2))
dfk = pd.DataFrame(df)

df1 = np.random.randint(40,50,size=(100,1))
df2 = np.hstack((df1,np.random.randint(0,101,size=(100,1))))
df3 = pd.DataFrame(df2)
plt.scatter(df3[0],df3[1])

final_stack = np.vstack((dfk,df3))
finaldfk = pd.DataFrame(final_stack)
plt.scatter(finaldfk[0],finaldfk[1])
plt.show()

# %%
a = np.array(finaldfa)
label_a = np.ones(len(a))
plt.scatter(a[:,0],a[:,1])
plt.show()

# %%
b = np.array(finaldfb)
b[:,0] = b[:,0]+70
label_b = np.ones(len(b))+1
plt.scatter(b[:,0],b[:,1])
plt.show()

# %%
h1 = np.array(finaldfh)
h1[:,0] = h1[:,0]+140
label_h1 = np.ones(len(h1))+2
plt.scatter(h1[:,0],h1[:,1])
plt.show()

# %%
i = np.array(finaldfi)
i[:,0] = i[:,0]+230
label_i = np.ones(len(i))+3
plt.scatter(i[:,0],i[:,1])
plt.show()

# %%
s = np.array(finaldfs)
s[:,0] = s[:,0]+280
label_s = np.ones(len(s))+4
plt.scatter(s[:,0],s[:,1])
plt.show()

# %%
h2 = np.array(finaldfh)
h2[:,0] = h2[:,0]+350
label_h2 = np.ones(len(h2))+5
plt.scatter(h2[:,0],h2[:,1])
plt.show()

# %%
e = np.array(finaldfe)
e[:,0] = e[:,0]+420
label_e = np.ones(len(e))+6
plt.scatter(e[:,0],e[:,1])
plt.show()

# %%
k = np.array(finaldfk)
k[:,0] = k[:,0]+500
k[:,1] = k[:,1]+100
label_k = np.ones(len(k))+7
plt.scatter(k[:,0],k[:,1])
plt.show()

# %%
plt.figure(figsize = (10,5))
final_label = np.concatenate((label_a,label_b,label_h1,label_i,label_s,label_h2,label_e,label_k))
finalstack = np.vstack((a,b,h1,i,s,h2,e,k))
plt.scatter(finalstack[:,0],finalstack[:,1],c=final_label )
plt.show()

# %%
final_label = final_label.reshape(len(final_label),1)

# %%
df = np.hstack((finalstack,final_label))

# %%
df = pd.DataFrame(df)
df
# Out:
#            0      1    2
# 0       55.0  184.0  1.0
# 1       52.0  114.0  1.0
# 2       56.0  168.0  1.0
# 3       52.0  148.0  1.0
# 4       54.0  196.0  1.0
# ...      ...    ...  ...
# 12895  542.0  159.0  8.0
# 12896  548.0  200.0  8.0
# 12897  540.0  137.0  8.0
# 12898  540.0  181.0  8.0
# 12899  544.0  130.0  8.0
#
# [12900 rows x 3 columns]

# %%
df.to_csv('/content/drive/MyDrive/Datasets/Synthetic_Dataset/name.csv',index=False)

# %%
df =pd.read_csv('/content/drive/MyDrive/Datasets/Synthetic_Dataset/name.csv')

# %%
plt.scatter(df.iloc[:,0],df.iloc[:,1],c= df.iloc[:,2])
plt.show()
